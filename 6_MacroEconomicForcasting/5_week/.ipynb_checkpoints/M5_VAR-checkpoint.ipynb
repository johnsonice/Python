# %% [markdown]
# # VAR - Reduced Form

# %%
## import all the modules need to be used
import statsmodels 
import statsmodels.tsa.stattools as tsa
import statsmodels.api as sm
import pandas as pd
import numpy as np
from IPython.display import Image
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline
import matplotlib.pylab
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %% [markdown]
# ## Quick demo of how to run VAR - Reduced form

# %%
## load sample data  -- Thailand inflation data from 2003m1 to 2014m12
df = pd.read_csv('../data/M5-Part I_VAR_Workfile_CAN.csv')
df['time'] = pd.to_datetime(df.dateid01)
df.index = df['time']
df.drop(['dateid','dateid01','lgdp_gap','lgdp'],axis = 1,inplace=True)   ## delete lgdp_gap, we will cancluate it ourselves

# %%
### some data transformation, calculate lgdp_gap 
df['lgdp'] = np.log(df.gdp)
cycle,trend = sm.tsa.filters.hpfilter(df.lgdp,1600)
df['lgdp_gap'] = cycle
df['lgdp_trend'] = trend
df.head()
# Out:
#              cpi     gdp      infl   mpr    rer   rer_gap       time  \
# time
# 1993-01-01  85.1  729128       NaN  5.98  97.41  4.104962 1993-01-01
# 1993-04-01  85.4  739668       NaN  4.54  95.27  2.521101 1993-04-01
# 1993-07-01  85.7  744268       NaN  4.23  93.41  1.214675 1993-07-01
# 1993-10-01  86.1  753308       NaN  4.27  92.41  0.761541 1993-10-01
# 1994-01-01  85.5  766924  0.470035  3.84  91.54  0.426801 1994-01-01
#
#                  lgdp  lgdp_gap  lgdp_trend
# time
# 1993-01-01  13.499605 -0.002062   13.501666
# 1993-04-01  13.513957  0.000188   13.513768
# 1993-07-01  13.520156 -0.005713   13.525869
# 1993-10-01  13.532229 -0.005739   13.537968
# 1994-01-01  13.550143  0.000084   13.550059

# %%
## prepare the VAR data 
## there are missing data for infl in the begaining, we need to drop na, eview does the same thing impliciately
data = df[['lgdp_gap','infl','rer_gap','mpr']]['1993-01-01':'2012-10-01'].dropna()

## run VAR model 
VAR_model = sm.tsa.VAR(data)
res = VAR_model.fit(4)

# %%
## see the summary results, it is the same as eviews output 
res.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 05, Oct, 2016
# Time:                     18:56:10
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -9.02746
# Nobs:                     74.0000    HQIC:                  -9.70122
# Log likelihood:          -8.51650    FPE:                3.93301e-05
# AIC:                     -10.1484    Det(Omega_mle):     2.48508e-05
# --------------------------------------------------------------------
# Results for equation lgdp_gap
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.001852         0.004244           -0.436           0.664
# L1.lgdp_gap         1.326326         0.134497            9.861           0.000
# L1.infl            -0.003931         0.001857           -2.117           0.038
# L1.rer_gap          0.000461         0.000408            1.129           0.263
# L1.mpr              0.001294         0.001914            0.676           0.501
# L2.lgdp_gap        -0.668620         0.129156           -5.177           0.000
# L2.infl             0.003031         0.001943            1.560           0.124
# L2.rer_gap          0.000153         0.000418            0.365           0.716
# L2.mpr             -0.000232         0.001896           -0.122           0.903
# ==============================================================================
#
# Results for equation infl
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               0.631097         0.292473            2.158           0.035
# L1.lgdp_gap        34.895534         9.267746            3.765           0.000
# L1.infl             0.602520         0.127949            4.709           0.000
# L1.rer_gap         -0.051604         0.028125           -1.835           0.071
# L1.mpr              0.063359         0.131872            0.480           0.633
# L2.lgdp_gap       -32.577225         8.899713           -3.660           0.001
# L2.infl             0.052881         0.133906            0.395           0.694
# L2.rer_gap          0.030782         0.028830            1.068           0.290
# L2.mpr             -0.050667         0.130669           -0.388           0.699
# ==============================================================================
#
# Results for equation rer_gap
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -1.264236         1.287082           -0.982           0.330
# L1.lgdp_gap        53.333646        40.784398            1.308           0.196
# L1.infl            -0.210156         0.563061           -0.373           0.710
# L1.rer_gap          0.944861         0.123769            7.634           0.000
# L1.mpr              0.168929         0.580325            0.291           0.772
# L2.lgdp_gap       -84.518338        39.164804           -2.158           0.035
# L2.infl             0.708689         0.589279            1.203           0.233
# L2.rer_gap         -0.331319         0.126873           -2.611           0.011
# L2.mpr             -0.050751         0.575031           -0.088           0.930
# ==============================================================================
#
# Results for equation mpr
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               0.429790         0.226893            1.894           0.063
# L1.lgdp_gap        14.748262         7.189677            2.051           0.044
# L1.infl            -0.109685         0.099259           -1.105           0.273
# L1.rer_gap          0.019414         0.021819            0.890           0.377
# L1.mpr              1.243381         0.102303           12.154           0.000
# L2.lgdp_gap       -10.050539         6.904167           -1.456           0.150
# L2.infl            -0.014173         0.103881           -0.136           0.892
# L2.rer_gap         -0.033853         0.022366           -1.514           0.135
# L2.mpr             -0.316676         0.101369           -3.124           0.003
# ==============================================================================
#
# Correlation matrix of residuals
#             lgdp_gap      infl   rer_gap       mpr
# lgdp_gap    1.000000  0.405660  0.343323  0.100732
# infl        0.405660  1.000000  0.060404  0.115761
# rer_gap     0.343323  0.060404  1.000000  0.057859
# mpr         0.100732  0.115761  0.057859  1.000000

# %%
## take a look the input series 
res.plot()

# %% [markdown]
# ### How to determine what is the correct lag length

# %% [markdown]
# 1. you can take a look at the auto corrolation for all the independent variables

# %%
## auto corrolation tables
res.plot_acorr()
# looks lik most of them, after 2 or 3 lags, things die down

# %%
## formally, you can use auto select functions 
## usually if you have monthly data, test 12, quarterly data test 4
VAR_model.select_order(4)

## from this result, i will probably just use 2 lags
# Out:
#                  VAR Order Selection
# =====================================================
#            aic          bic          fpe         hqic
# -----------------------------------------------------
# 0       -5.029       -4.903     0.006542       -4.979
# 1       -9.782       -9.149    5.653e-05       -9.530
# 2       -10.31      -9.175*    3.337e-05      -9.860*
# 3       -10.31       -8.668    3.375e-05       -9.658
# 4      -10.53*       -8.383   2.762e-05*       -9.677
# =====================================================
# * Minimum
# {'aic': 4, 'bic': 2, 'fpe': 4, 'hqic': 2}

# %% [markdown]
# ## How to test the stationarity of VAR model

# %%
## the var result object will return roots, we can plot them 
## to make it the same as Eview, we will take the inverse of it, and see if all of them are inside the unit circly
roots_inve = 1/res.roots
unit_circle = plt.Circle((0, 0), 1, color='r',fill=False)

fig,ax = plt.subplots(figsize=(4,4))
plt.axis([-2, 2, -2, 2])
ax.scatter(roots_inve.real,roots_inve.imag)
ax.add_artist(unit_circle)

## from this result, we can see that roots are all within the circle. so we are good

# %% [markdown]
# ## How we check residuals

# %%
## plot the residuals
res.resid.plot()
## in general they seems to be stationary, there are some big variance in financial crisis,they could
## be a proble

# %%
acf = tsa.acf(res.resid.lgdp_gap, qstat=True, fft=True, alpha=True)
acf_pd = pd.DataFrame(list(acf)).T
acf_pd.columns = ['acf','confint','qstat','pvalues']
acf_pd.head(13)
# Out:
#            acf                                 confint     qstat   pvalues
# 0            1                              [1.0, 1.0]  0.100841  0.750823
# 1    0.0366578      [0.0366577679449, 0.0366577679449]  0.182602  0.912743
# 2    0.0327747      [0.0327747454493, 0.0327747454493]  0.185356  0.979918
# 3   0.00597172    [0.00597171939755, 0.00597171939755]   3.20368  0.524338
# 4     -0.19627      [-0.196270469217, -0.196270469217]   3.22904  0.664722
# 5   -0.0178595    [-0.0178594709572, -0.0178594709572]   3.65314  0.723496
# 6   -0.0724808    [-0.0724807513083, -0.0724807513083]   3.96843  0.783406
# 7   -0.0620201    [-0.0620201387728, -0.0620201387728]   4.47894  0.811537
# 8   -0.0783082    [-0.0783082073105, -0.0783082073105]   4.48194  0.876933
# 9  -0.00596473  [-0.00596473311883, -0.00596473311883]   8.74949  0.556032
# 10    0.222845        [0.222844986123, 0.222844986123]   9.38909  0.586025
# 11   -0.085573    [-0.0855729558626, -0.0855729558626]   9.49029   0.66058
# 12    0.033759        [0.033758999158, 0.033758999158]   10.2122  0.676493

# %%
acf = sm.graphics.tsa.plot_acf(res.resid,lags = 20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-c062b8fd0bb3> in <module>()
# ----> 1 acf = sm.graphics.tsa.plot_acf(res.resid,lags = 20)
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/statsmodels/graphics/tsaplots.py in plot_acf(x, ax, lags, alpha, use_vlines, unbiased, fft, **kwargs)
#      69
#      70     acf_x, confint = acf(x, nlags=nlags, alpha=alpha, fft=fft,
# ---> 71                          unbiased=unbiased)
#      72
#      73     if use_vlines:
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/statsmodels/tsa/stattools.py in acf(x, unbiased, nlags, qstat, fft, alpha)
#     408     d = nobs  # changes if unbiased
#     409     if not fft:
# --> 410         avf = acovf(x, unbiased=unbiased, demean=True)
#     411         #acf = np.take(avf/avf[0], range(1,nlags+1))
#     412         acf = avf[:nlags + 1] / avf[0]
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/statsmodels/tsa/stattools.py in acovf(x, unbiased, demean, fft)
#     307     x = np.squeeze(np.asarray(x))
#     308     if x.ndim > 1:
# --> 309         raise ValueError("x must be 1d. Got %d dims." % x.ndim)
#     310     n = len(x)
#     311
#
# ValueError: x must be 1d. Got 2 dims.

# %%
res.resid
# Out:
#             lgdp_gap      infl   rer_gap       mpr
# time
# 1995-01-01  0.005240  0.112704 -1.561926  1.187082
# 1995-04-01 -0.000845  0.268785  0.434787 -0.440267
# 1995-07-01  0.002266 -0.224401 -0.263911 -0.199133
# 1995-10-01 -0.004117 -0.196855 -1.146312 -0.263509
# 1996-01-01 -0.008814 -0.506449  0.215825 -0.399651
# 1996-04-01 -0.003227 -0.198838  1.603423  0.401425
# 1996-07-01 -0.000463  0.003001  0.533309 -0.135085
# 1996-10-01  0.000443  0.481051  2.664064 -0.670118
# 1997-01-01  0.000352  0.250554  1.552307  0.338957
# 1997-04-01 -0.001021 -0.168509  1.196500  0.191458
# 1997-07-01  0.001568 -0.088911  1.775501  0.626939
# 1997-10-01 -0.004358 -0.566937 -0.570749  0.392223
# 1998-01-01 -0.005022 -0.191338  0.703777  0.656973
# 1998-04-01 -0.015549 -0.408941  0.162563 -0.284503
# 1998-07-01 -0.010324 -0.003578 -2.163770  0.435110
# 1998-10-01 -0.001930  0.327407 -1.641164 -0.166385
# 1999-01-01 -0.003021 -0.569527  0.045458 -0.119071
# 1999-04-01 -0.003012  0.055231  0.366058 -0.772850
# 1999-07-01  0.005138  0.060813 -1.540378 -0.176287
# 1999-10-01  0.000603 -0.156667  0.920488  0.213728
# 2000-01-01  0.008412 -0.023886  0.935263  0.401242
# 2000-04-01  0.010289 -0.525884 -1.568413  0.434645
# 2000-07-01  0.002626 -0.437795 -0.062598  0.030386
# 2000-10-01 -0.001911 -0.014071 -1.837846 -0.129152
# 2001-01-01  0.012108  0.017406  1.573187 -0.134730
# 2001-04-01 -0.005714  0.985928 -0.995889 -0.361839
# 2001-07-01 -0.007932  0.285688  0.803923  0.269674
# 2001-10-01  0.000331 -0.003855 -0.342073 -0.406716
# 2002-01-01  0.001026  0.359799 -2.460172  0.241333
# 2002-04-01  0.005622  0.002240  0.221305  0.457487
# ...              ...       ...       ...       ...
# 2005-07-01  0.007441  0.535683  1.510689 -0.014444
# 2005-10-01  0.005632 -0.205836  0.380597  0.190566
# 2006-01-01 -0.000283  0.077998  0.850231  0.151907
# 2006-04-01 -0.003894  0.000732  2.464222  0.484436
# 2006-07-01  0.001535  0.043842  0.649836  0.304315
# 2006-10-01 -0.006900 -0.142124 -2.312588  0.117206
# 2007-01-01  0.008597  0.320897 -2.990266 -0.023846
# 2007-04-01  0.008747 -0.164841  5.480342 -0.142036
# 2007-07-01 -0.002739 -0.191367  2.571877 -0.049644
# 2007-10-01  0.014916  0.550710  8.081306 -0.031709
# 2008-01-01  0.003035 -0.132250 -2.577441  0.025864
# 2008-04-01  0.014505  0.242887  1.900951 -0.276331
# 2008-07-01  0.001533  0.491835 -1.377268 -0.002711
# 2008-10-01 -0.024362 -0.828641 -9.583158 -0.622349
# 2009-01-01 -0.003891 -0.376580  0.936197 -0.058052
# 2009-04-01  0.005228  0.015477  1.267273 -0.099526
# 2009-07-01  0.003496 -0.192226 -0.322623  0.168729
# 2009-10-01  0.001323  0.139731 -1.377261 -0.163965
# 2010-01-01 -0.005871 -0.396281 -0.537552 -0.308991
# 2010-04-01 -0.011161 -0.923448  1.299887 -0.273318
# 2010-07-01 -0.007494 -0.287747 -3.187819 -0.022572
# 2010-10-01  0.008252  0.362287  1.961220 -0.008622
# 2011-01-01  0.003737  0.410223  0.598795 -0.188046
# 2011-04-01 -0.004733  0.866532  0.507743 -0.426539
# 2011-07-01  0.013315  0.581618  0.870781 -0.009350
# 2011-10-01  0.002353  0.035749 -3.470967  0.081607
# 2012-01-01 -0.002318 -0.437372  2.947644 -0.133999
# 2012-04-01  0.000667 -0.331883 -0.062764 -0.316191
# 2012-07-01  0.003054 -0.193813  3.549644 -0.141709
# 2012-10-01 -0.007037 -0.215080  0.833772 -0.096599
#
# [72 rows x 4 columns]

# %%
## look at residual corrolations 
print (res.names)
res.resid_corr
## because it is a reduced from VAR, so there will be some corrolation between errors in differnt equasion
# Out:
# ['lgdp_gap', 'infl', 'rer_gap', 'mpr']
# array([[ 1.        ,  0.40565975,  0.34332275,  0.10073191],
#        [ 0.40565975,  1.        ,  0.06040376,  0.11576059],
#        [ 0.34332275,  0.06040376,  1.        ,  0.05785921],
#        [ 0.10073191,  0.11576059,  0.05785921,  1.        ]])
