# %% [markdown]
# ## Notes for NumPy and Pandas

# %%
## import all libs 
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
## some sample data 

df = pd.read_csv('data/CDIS.csv',encoding = 'iso-8859-1')
var_names = df.columns.values
droplist = [x for x in var_names if x.startswith("Status")]        # pick out all columns with Status
df.drop(droplist,axis=1,inplace=True)                              # drop all columns with 'Status'
df.columns.values[0] = "Country Name"                              # change column name by index
df.describe()
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#         Country Code  Counterpart Country Code    Time Period  \
# count  237575.000000             237575.000000  237575.000000
# mean      521.265760                521.265760    2012.055107
# std       287.596682                287.596682       1.982916
# min         1.000000                  1.000000    2008.000000
# 25%       228.000000                228.000000    2010.000000
# 50%       532.000000                532.000000    2012.000000
# 75%       754.000000                754.000000    2014.000000
# max       968.000000                968.000000    2015.000000
#
#        Inward Debt Instruments Assets Positions (Gross), Derived, US Dollars (IIWDA_DV_BP6_USD)  \
# count                                       7.322200e+04
# mean                                        1.630679e+09
# std                                         3.332054e+10
# min                                        -1.088700e+07
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         2.742392e+12
#
#        Inward Debt Instruments Assets Positions (Gross), US Dollars (IIWDA_BP6_USD)  \
# count                                       8.854600e+04
# mean                                        1.591084e+09
# std                                         3.621399e+10
# min                                        -4.825303e+07
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         2.933063e+12
#
#        Inward Debt Instruments Liabilities Positions (Gross), Derived, US Dollars (IIWDL_DV_BP6_USD)  \
# count                                       7.440600e+04
# mean                                        3.402885e+09
# std                                         6.639877e+10
# min                                        -2.327921e+08
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         4.841031e+12
#
#        Inward Debt Instruments Liabilities Positions (Gross), US Dollars (IIWDL_BP6_USD)  \
# count                                       9.150800e+04
# mean                                        3.536907e+09
# std                                         7.676573e+10
# min                                        -1.708170e+08
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         6.154274e+12
#
#        Inward Debt Instruments Positions (Net), Derived, US Dollars (IIWD_DV_BP6_USD)  \
# count                                       8.933300e+04
# mean                                        1.905476e+09
# std                                         4.316912e+10
# min                                        -1.851215e+11
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         3.618041e+12
#
#        Inward Debt Instruments Positions (Net), US Dollars (IIWD_BP6_USD)  \
# count                                       1.158060e+05
# mean                                        1.911349e+09
# std                                         4.602043e+10
# min                                        -3.627969e+11
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         4.610997e+12
#
#        Inward Debt Positions (Net): Resident Enterprises that are not Financial Intermediaries, Derived, US Dollars (IIWDN_DV_BP6_USD)  \
# count                                       6.458400e+04
# mean                                        4.538379e+08
# std                                         1.091484e+10
# min                                        -2.580125e+11
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         9.243901e+11
#
#           ...       \
# count     ...
# mean      ...
# std       ...
# min       ...
# 25%       ...
# 50%       ...
# 75%       ...
# max       ...
#
#        Outward Direct Investment Assets Positions (Gross) with Fellow Enterprises, US Dollars (IOWFA_BP6_USD)  \
# count                                       5.226900e+04
# mean                                        5.179706e+08
# std                                         9.857484e+09
# min                                        -5.474280e+06
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         5.738566e+11
#
#        Outward Direct Investment Liabilities Positions (Gross) with Fellow Enterprises, Derived, US Dollars (IOWFL_DV_BP6_USD)  \
# count                                       6.543700e+04
# mean                                        9.049068e+08
# std                                         1.914290e+10
# min                                        -2.673754e+08
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         1.421879e+12
#
#        Outward Direct Investment Liabilities Positions (Gross) with Fellow Enterprises, US Dollars (IOWFL_BP6_USD)  \
# count                                       5.148300e+04
# mean                                        3.151639e+08
# std                                         6.996283e+09
# min                                        -2.800000e+04
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         4.788249e+11
#
#        Outward Direct Investment Positions (Net) with Fellow Enterprises, Derived, US Dollars (IOWF_DV_BP6_USD)  \
# count                                       7.486800e+04
# mean                                        1.491363e+08
# std                                         6.711428e+09
# min                                        -3.893596e+11
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         3.565499e+11
#
#        Outward Direct Investment Positions (Net) with Fellow Enterprises, US Dollars (IOWF_BP6_USD)  \
# count                                       5.585900e+04
# mean                                        1.953056e+08
# std                                         5.428370e+09
# min                                        -4.823654e+10
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         4.269829e+11
#
#        Outward Direct Investment Positions, Derived, US Dollars (IOW_DV_BP6_USD)  \
# count                                       1.272840e+05
# mean                                        1.208221e+10
# std                                         2.748521e+11
# min                                        -5.793580e+10
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         2.840560e+13
#
#        Outward Direct Investment Positions, US Dollars (IOW_BP6_USD)  \
# count                                       9.484000e+04
# mean                                        1.598377e+10
# std                                         3.273461e+11
# min                                        -2.262867e+10
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         2.824419e+13
#
#        Outward Equity Positions (Net), Derived, US Dollars (IOWE_DV_BP6_USD)  \
# count                                       1.139040e+05
# mean                                        1.069599e+10
# std                                         2.345504e+11
# min                                        -7.281202e+09
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                         2.307549e+13
#
#        Outward Equity Positions (Net), US Dollars (IOWE_BP6_USD)  Unnamed: 85
# count                                       8.783600e+04                  0.0
# mean                                        1.464639e+10                  NaN
# std                                         2.927280e+11                  NaN
# min                                        -9.048252e+09                  NaN
# 25%                                                  NaN                  NaN
# 50%                                                  NaN                  NaN
# 75%                                                  NaN                  NaN
# max                                         2.516573e+13                  NaN
#
# [8 rows x 44 columns]

# %% [markdown]
# ### Some Numpy functions

# %%
points=np.arange(-5,5,0.01)                         # create evenly spaced intervals
zero_series = np.zeros((5,5))                       # 5 by 5, all 0 matrix
arr = np.random.randn(5,5)                          # 5 by 5  random numbers
new_arr= np.where(arr<0,0,arr)                      # numpy logical filter, recode negative to 0s

# create some data
countries = np.array(['France','Germany','Mexico','Russia','USA','Germany','China','China'])

np.unique(countries)                                # get unique values of a list values
np.in1d(['France','USA','Sweden'],countries)        # check if items in an array
# Out:
# array([ True,  True, False], dtype=bool)

# %% [markdown]
# ### Some pandas functions

# %%
###############################################
## change column name and conditional slicing##
###############################################
colnames = ['country','year','PPPPC','rule_law','control_corruption','regulatory_quality']
df[colnames].head()                                                          # Easy way to get multiple columns from a df
df[:3][['country','year','PPPPC']]                                           # retrieve certain rows and columns
df.ix[:,0:5]                                                                 # select rows and columns by location
df[(df.PPPPC>10000) & (df.rule_law>0)]                                       # retrieve row based on columns values 
df['year'] = np.arange(df.shape[0])                                          # assing value from 0 to length
df.index.values                                                              # values of all row indexes
df.columns.values                                                            # show all columns names 
df.columns =['a','b']                                                        # change columns names directly
df.columns.names=['Cities']                                                  # change all columns index name
#df = df.rename(columns={'control_corruption':'corruption'})                 # change column name 
#df.drop(0)                                                                  # drop row
#df.drop('regulatory_quality',axis=1)                                        # drop a column, use axis 1 


# selecting country data based multiple conditions, and create a copy instead of view
USA = df.ix[:,4:6][(df['Country Code']== 111) & (df['Counterpart Country Name'] == 'Japan')].copy()
Japan = df.ix[:,4:6][(df['Country Name']== 'Japan') & (df['Counterpart Country Name'] == 'United States')].copy()
# for some reason, even with copy, the column names are still linked, so i recreated df using the copyed data
df_USA = pd.DataFrame(USA.values,columns=['year','USA_values'])
df_Japan = pd.DataFrame(Japan.values,columns=['year','Japan_values'])


## select rows based on a list of values 
keep_country = [111,112,158,146,170,576,532,924]
df_test = df_2015[(df_2015.countrycode.isin(keep_country))& df_2015.counterpart_code.isin(keep_country)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a315ee30d8c3> in <module>()
#       3 ######################
#       4 colnames = ['country','year','PPPPC','rule_law','control_corruption','regulatory_quality']
# ----> 5 df[colnames].head()                                                          # Easy way to get multiple columns from a df
#       6 df[:3][['country','year','PPPPC']]                                           # retrieve certain rows and columns
#       7 df.ix[:,0:5]                                                                 # select rows and columns by location
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1989         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1990             # either boolean or fancy integer index
# -> 1991             return self._getitem_array(key)
#    1992         elif isinstance(key, DataFrame):
#    1993             return self._getitem_frame(key)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2033             return self.take(indexer, axis=0, convert=False)
#    2034         else:
# -> 2035             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2036             return self.take(indexer, axis=1, convert=True)
#    2037
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1212                 mask = check == -1
#    1213                 if mask.any():
# -> 1214                     raise KeyError('%s not in index' % objarr[mask])
#    1215
#    1216                 return _values_from_object(indexer)
#
# KeyError: "['country' 'year' 'PPPPC' 'rule_law' 'control_corruption'\n 'regulatory_quality'] not in index"

# %%
#####################
## some statistics ##
#####################

#create some data
df_na = DataFrame([[1,2,3],[np.nan,5,6],[7,np.nan,9],[np.nan,np.nan,np.nan]])

df.describe()                                                                # summrize all variables 
df.PPPPC.cumsum()                                                            # accumulative sum
df.min(axis=1)                                                               # row sum, min or others  
df_na.dropna()                                                               # drop row when there is na anywhere
df_na.dropna(axis=1)                                                         # drop columns with missing data
df_na.isnull()                                                               # return boolean list
df_na.fillna(0,inplace=True)                                                 # fill na with 0, and change the original df 

df.sum(level='Temp',axis=1)                                                  # aggregations by group

# %%
########################
### minipulatiogn data #
########################
df = pd.read_csv('data/data.csv',encoding = 'iso-8859-1')

df.loc[df.rule_law<0,'rule_law']=0                                         ## recode values, change all negative values to 0
df['log_value'] = np.log(df.rule_law)                                      ## create another logged series

# %%
##############
## merging ###
##############

#the union of both keys, merge and add addition keys
df_merge = pd.merge(df_USA,df_Japan,on='year',how='outer') 
print(df_merge)

####### other merge types ####
# pd.merge(df1,df2,on='key')                   #only merged together where keys are in common 
# pd.merge(df1,df2,on='key',how='left')              #only keep left
# pd.merge(df1,df2,on='key',how='right')             #only keep right 
# pd.merge(df1,df2,on='key',how='outer')             #the union of both keys, merge and add addition keys

### merge on multiple columns ####
df3 = DataFrame({'key1': ['X', 'y', 'z', 'a', 'b', 'c'],
                 'key2':[1,2,3,4,5,6],
                 'data_set_3': range(6)})
df4 = DataFrame({'key1': ['Y', 'a', 'X', 'b', 'Z'],
                 'key2':[2,4,1,3,5],
                 'data_set_4': range(5)})

pd.merge(df3,df4,on=['key1','key2'],how='left')                          #keep only left, on multiple keys

# %%
###########################
#### panda df concatenate 
###########################
#similar to stata append 
df1 = DataFrame(np.random.randn(4,3),columns=['x','y','z'])
df2 = DataFrame(np.random.randn(3, 3), columns=['y', 'q', 'x'])
pd.concat([df1,df2],ignore_index=True)                   #similar to stata append

# %%
##################################
## combine series into dataframe##
##################################

## some data
country_name = df['Country Name']
country_code = df['Country Code']
year = df['Time Period']

## reading multiple arrays into dataframe
df_time =pd.concat([country_name,country_code,year],axis=1) 
print (df_time.head())

## an alternatively way, combining numpy arries into dataframe
## but this is significantly slower
df_time = pd.DataFrame(np.array([country_name.tolist(),country_code.tolist(),year.tolist()]).T,columns=['name','code','year'])
df_time.head()

# %% [markdown]
# ### Pandas with Time Series

# %%
## something
